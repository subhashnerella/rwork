# %%
import numpy
import math
from matplotlib import pyplot

# %%
xc=0.75
yc=0.75

# %%
R = 5+xc
a= xc-R
g=1-(xc/a)
cc=yc/g
Rc= R/g
theta = numpy.linspace(0,2*numpy.pi,150)
radius_matrix, theta_matrix = numpy.meshgrid(R,theta)

# %%
X = radius_matrix * numpy.cos(theta_matrix)+xc
Y = radius_matrix * numpy.sin(theta_matrix)+yc

# %%
phi= numpy.linspace(numpy.arctan(cc/a),numpy.pi-numpy.arctan(cc/a),150)
crad_matrix, cphi_matrix = numpy.meshgrid(Rc, phi)

XC=crad_matrix * numpy.cos(cphi_matrix)
YC=crad_matrix * numpy.sin(cphi_matrix)+cc

# %%
# %matplotlib inline

# plots the grid of points
size = 5
pyplot.figure(figsize=(size, size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.grid(True)
pyplot.plot(X, Y, color='r')
pyplot.plot(XC, YC, color='b')
pyplot.scatter(xc,yc)
pyplot.scatter(0,cc, color='b')
pyplot.plot([0.75,0,-4.951],[0.75,cc,0],color='#CD2305')

# %%
E = X+1j*Y
EC = XC+1j*YC

# %%
Z = E+((R-xc)**2)/E
ZC = EC+((R-xc)**2)/EC

# %%
Xe ,Ye=Z.real ,Z.imag
Xce ,Yce=ZC.real ,ZC.imag

# %%
# %matplotlib inline

# plots the grid of points
size = 5
pyplot.figure(figsize=(size, size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.grid(True)
pyplot.ylim(-2*R,2*R)
#pyplot.xlim(x_start, x_end)
#pyplot.ylim(y_start, y_end)
pyplot.plot(Xe, Ye, color='#CD2305')
pyplot.plot(Xce, Yce, color='b')

# %%
camber=-8*a*numpy.arctan(cc/a)/numpy.sin(2*numpy.arctan(cc/a))
re=40000
thE=2*camber/re**0.5
thR=2*thE

# %%
gamma= numpy.linspace(1,g,41)

rgamma=numpy.linspace(1,g,41)*(a**2+cc**2)**0.5
rgamma1=numpy.linspace(1,g,41)*((a**2+cc**2)**0.5+thE)
rgamma2=numpy.linspace(1,g,41)*((a**2+cc**2)**0.5+thR)
gamma_mat, theta_mat=numpy.meshgrid(rgamma,theta)
gamma_mat1, theta_mat=numpy.meshgrid(rgamma1,theta)
gamma_mat2, theta_mat=numpy.meshgrid(rgamma2,theta)
X = gamma_mat * numpy.cos(theta_mat)+(1-gamma)*a
Y = gamma_mat * numpy.sin(theta_mat)+gamma*cc

X1 = gamma_mat1 * numpy.cos(theta_mat)+(1-gamma)*a
Y1 = gamma_mat1 * numpy.sin(theta_mat)+gamma*cc
X2 = gamma_mat2 * numpy.cos(theta_mat)+(1-gamma)*a
Y2= gamma_mat2 * numpy.sin(theta_mat)+gamma*cc

# %%
# plots the grid of points
size = 5
pyplot.figure(figsize=(size, size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.grid(True)
pyplot.plot(X, Y, color='b');
#pyplot.scatter(X1, Y1, color='r')
#pyplot.plot(X2, Y2, color='y')

# %%
zeta=X+1J*Y

Z=zeta+a**2/zeta
Xe ,Ye=Z.real ,Z.imag

# %%
# plots the grid of points
size = 5
#pyplot.figure(figsize=(size, size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.grid(True)
pyplot.ylim(-2*R,2*R)
pyplot.plot(Xe, Ye, color='b');
#pyplot.scatter(X1, Y1, color='r')
#pyplot.plot(X2, Y2, color='y')

# %%
rgamma=g*(a**2+cc**2)**0.5
rgamma1=g*((a**2+cc**2)**0.5+thE)
rgamma2=g*((a**2+cc**2)**0.5+thR)
gamma_mat, theta_mat=numpy.meshgrid(rgamma,theta)
gamma_mat1, theta_mat=numpy.meshgrid(rgamma1,theta)
gamma_mat2, theta_mat=numpy.meshgrid(rgamma2,theta)
X = gamma_mat * numpy.cos(theta_mat)+(1-g)*a
Y = gamma_mat * numpy.sin(theta_mat)+g*cc
X1 = gamma_mat1 * numpy.cos(theta_mat)+(1-g)*a
Y1 = gamma_mat1 * numpy.sin(theta_mat)+g*cc
X2 = gamma_mat2 * numpy.cos(theta_mat)+(1-g)*a
Y2= gamma_mat2 * numpy.sin(theta_mat)+g*cc

# %%
# plots the grid of points
size = 5
pyplot.figure(figsize=(size, size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.grid(True)
pyplot.plot(X, Y, color='b')
pyplot.plot(X1, Y1, color='r')
pyplot.plot(X2, Y2, color='y')

# %%
zeta=X+1J*Y
zeta1=X1+1J*Y1
zeta2=X2+1J*Y2
Z=zeta+a**2/zeta
Z1=zeta1+a**2/zeta1
Z2=zeta2+a**2/zeta2
Xe ,Ye=Z.real ,Z.imag
Xe1 ,Ye1=Z1.real ,Z1.imag
Xe2 ,Ye2=Z2.real ,Z2.imag

# %%
# plots the grid of points

pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.grid(True)
pyplot.ylim(-2*R,2*R)
pyplot.plot(Xe, Ye, color='b')
pyplot.plot(Xe1, Ye1, color='r')
pyplot.plot(Xe2, Ye2, color='y')

# %%
theta1=numpy.linspace(-numpy.pi/2,numpy.pi/2,150)
theta2=numpy.linspace(numpy.pi/2,3*numpy.pi/2,150)
rgamma=numpy.linspace(1,g,41)*(a**2+cc**2)**0.5

gamma_mat1, theta_mat1=numpy.meshgrid(rgamma,theta1)
gamma_mat2, theta_mat2=numpy.meshgrid(rgamma,theta2)
X = gamma_mat1 * numpy.cos(theta_mat1)+(1-gamma)*a
Y = gamma_mat1 * numpy.sin(theta_mat1)+gamma*cc
X2 = gamma_mat2 * numpy.cos(theta_mat2)+(1-gamma)*a
Y2 = gamma_mat2 * numpy.sin(theta_mat2)+gamma*cc

# %%
size = 5
pyplot.figure(figsize=(size, size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.grid(True)
pyplot.plot(X, Y, color='b');
pyplot.plot(X2, Y2, color='r');

# %%
zeta1= X+1j*Y
zeta2= X2+1j*Y2
Z1=zeta1+a**2/zeta1
Z2=zeta2+a**2/zeta2
X1, Y1= Z1.real, Z1.imag
X2, Y2= Z2.real, Z2.imag

# %%
size = 5
pyplot.figure(figsize=(size, size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.grid(True)
pyplot.ylim(-2*R,2*R)
pyplot.plot(X1, Y1, color='b');
pyplot.plot(X2, Y2, color='r');
